# %% [markdown]
# ## Install Dependencies

# %%
#@title Install and Import Dependencies

# this assumes that you have a relevant version of PyTorch installed
# !pip install -q torchaudio

SAMPLING_RATE = 16000

import torch
torch.set_num_threads(1)

from IPython.display import Audio
from pprint import pprint
# download example
torch.hub.download_url_to_file('https://models.silero.ai/vad_models/en.wav', 'en_example.wav')
# Out:
# 100%|██████████| 1.83M/1.83M [00:00<00:00, 2.15MB/s]

# %%
USE_PIP = True # download model using pip package or torch.hub
USE_ONNX = False # change this to True if you want to test onnx model
if USE_ONNX:
    # !pip install -q onnxruntime
if USE_PIP:
  # !pip install -q silero-vad
  from silero_vad import (load_silero_vad,
                          read_audio,
                          get_speech_timestamps,
                          save_audio,
                          VADIterator,
                          collect_chunks)
  model = load_silero_vad(onnx=USE_ONNX)
else:
  model, utils = torch.hub.load(repo_or_dir='snakers4/silero-vad',
                                model='silero_vad',
                                force_reload=True,
                                onnx=USE_ONNX)

  (get_speech_timestamps,
  save_audio,
  read_audio,
  VADIterator,
  collect_chunks) = utils

# %% [markdown]
# ## Speech timestapms from full audio

# %%
import pandas as pd
import numpy as np
import os
import torch
import torchaudio
from glob import glob
from pprint import pprint
from tqdm.auto import tqdm

def process_dataset(dataset_path, output_file):
    SAMPLING_RATE = 16000
    """
    Process all audio files in the dataset directory and save timestamps to a text file.
    
    Args:
        dataset_path: Path to the directory containing audio files
        output_file: Path to the output text file
    """
    # Get all audio files in the dataset directory
    audio_files = []
    for ext in ['*.wav', '*.mp3', '*.flac', '*.ogg']:
        audio_files.extend(glob(os.path.join(dataset_path, ext)))
    
    print(f"Found {len(audio_files)} audio files in {dataset_path}")
    
    # Create or open the output file
    with open(output_file, 'w') as f:
        # Write header
        f.write("ID,timestamp_start,timestamp_stop\n")
        
        # Process each audio file
        for audio_file in audio_files:
            # Get the recording ID (filename without extension)
            file_name = os.path.basename(audio_file)
            ID = os.path.splitext(file_name)[0]
            print(f"Processing {ID}...")
            
            # Check if this is a "_non_speech" file - if so, skip VAD processing
            if "_non_speech" in ID:
                print(f"Detected non-speech file {ID}, skipping VAD processing")
                continue
                
            # Check if this is a "_speech" file - if so, process the whole file as speech
            if "_speech" in ID:
                try:
                    # Read the audio file to get duration
                    wav = read_audio(audio_file, sampling_rate=SAMPLING_RATE)
                    duration_frames = len(wav)
                    
                    # Write the entire file as speech
                    start_time = 0
                    end_time = duration_frames / SAMPLING_RATE
                    f.write(f"{ID},{start_time:.3f},{end_time:.3f}\n")
                    print(f"Marked entire file {ID} as speech")
                    continue
                except Exception as e:
                    print(f"Error processing {ID}: {e}")
                    continue
            
            try:
                # Read the audio file
                wav = read_audio(audio_file, sampling_rate=SAMPLING_RATE)
                
                # Get speech timestamps
                speech_timestamps = get_speech_timestamps(wav, model, sampling_rate=SAMPLING_RATE)
                
                # Debug: Print timestamps
                print(f"Found {len(speech_timestamps)} speech segments in {ID}")
                
                # Write timestamps to file
                for ts in speech_timestamps:
                    # Convert frame indices to seconds
                    start_time = ts['start'] / SAMPLING_RATE
                    end_time = ts['end'] / SAMPLING_RATE
                    
                    # Write to file
                    f.write(f"{ID},{start_time:.3f},{end_time:.3f}\n")
                    
            except Exception as e:
                print(f"Error processing {ID}: {e}")
    
    print(f"Processing complete. Results saved to {output_file}")

def label_speech_windows(features_csv_path, timestamps_txt_path, output_csv_path=None, window_size=0.025, overlap=0.6):
    """
    Label each window in the features CSV as speech (1) or non-speech (0) based on timestamps.
    
    Args:
        features_csv_path: Path to CSV file containing features for each window
        timestamps_txt_path: Path to text file containing speech timestamps
        output_csv_path: Path to save the output CSV file (default: append '_labeled' to input filename)
        window_size: Window size in seconds (default: 0.025s = 25ms)
        overlap: Overlap between windows (default: 0.6)
    
    Returns:
        DataFrame with an additional 'speech_label' column
    """
    # Set default output path if not provided
    if output_csv_path is None:
        base_name = os.path.splitext(features_csv_path)[0]
        output_csv_path = f"{base_name}_labeled.csv"
    
    print(f"Loading features from {features_csv_path}...")
    # Load features CSV
    features_df = pd.read_csv(features_csv_path)
    
    print(f"Loading timestamps from {timestamps_txt_path}...")
    # Load timestamps
    if os.path.exists(timestamps_txt_path) and os.path.getsize(timestamps_txt_path) > 0:
        timestamps_df = pd.read_csv(timestamps_txt_path)
        timestamp_groups = timestamps_df.groupby('ID')
    else:
        print("Warning: Timestamps file is empty or does not exist. All windows will be labeled as non-speech.")
        timestamps_df = pd.DataFrame(columns=['ID', 'timestamp_start', 'timestamp_stop'])
        timestamp_groups = pd.DataFrame().groupby('ID')  # Empty group
    
    # Calculate the step size between windows
    step_size = window_size * (1 - overlap)
    
    # Initialize speech labels with zeros (non-speech)
    speech_labels = np.zeros(len(features_df), dtype=int)
    
    # Add a new column for window times if it doesn't exist
    if 'window_time' not in features_df.columns:
        # Assume windows are ordered sequentially within each recording
        # Create a temporary column for window indices
        features_df['window_idx'] = features_df.groupby('ID').cumcount()
        # Calculate window time (start time of each window)
        features_df['window_time'] = features_df['window_idx'] * step_size
        # Remove temporary column
        features_df.drop('window_idx', axis=1, inplace=True)
    
    print("Labeling windows...")
    # For each recording in the features DataFrame
    for ID, group in tqdm(features_df.groupby('ID')):
        # Get indices in the original DataFrame
        indices = group.index
        
        # Automatically label based on filename pattern
        if "_non_speech" in ID:
            # Mark all windows in this recording as non-speech (0)
            speech_labels[indices] = 0
            print(f"Auto-labeled all windows in {ID} as non-speech based on filename pattern")
            continue
        elif "_speech" in ID:
            # Mark all windows in this recording as speech (1)
            speech_labels[indices] = 1
            print(f"Auto-labeled all windows in {ID} as speech based on filename pattern")
            continue
        
        # Skip if this recording is not in the timestamps file and apply default non-speech label
        if ID not in timestamp_groups.groups:
            print(f"No timestamps found for recording {ID}, labeling as non-speech")
            speech_labels[indices] = 0
            continue
        
        # Get timestamps for this recording
        recording_timestamps = timestamp_groups.get_group(ID)
        
        # For each window in this recording
        for i, (idx, row) in enumerate(group.iterrows()):
            window_start = row['window_time']
            window_end = window_start + window_size
            
            # Check if this window overlaps with any speech segment
            for _, ts_row in recording_timestamps.iterrows():
                ts_start = ts_row['timestamp_start']
                ts_end = ts_row['timestamp_stop']
                
                # Check for overlap
                if max(window_start, ts_start) < min(window_end, ts_end):
                    speech_labels[idx] = 1
                    break  # No need to check other timestamps for this window
    
    # Add speech labels to the DataFrame
    features_df['speech_label'] = speech_labels
    
    # Save the result
    print(f"Saving labeled features to {output_csv_path}...")
    features_df.to_csv(output_csv_path, index=False)
    
    print(f"Done! Added speech labels for {sum(speech_labels)} windows out of {len(speech_labels)} total.")
    
    return features_df

# Example usage
if __name__ == "__main__":
    
    dataset_path = "C://Users//costac_c//Documents//GitHub//VAD//database//timit"
    output_file = "speech_timestamps.txt"

    process_dataset(dataset_path, output_file)

    features_csv_path = "C://Users//costac_c//Documents//GitHub//VAD//database//features//16000_25_0.6_hamming_none_MAV_ZCR_F0_TTP_EQClasses.csv"
    timestamps_txt_path = "C://Users//costac_c//Documents//GitHub//VAD//silero-vad//speech_timestamps.txt"
    
    # Run the labeling
    labeled_df = label_speech_windows(
        features_csv_path=features_csv_path,
        timestamps_txt_path=timestamps_txt_path,
        window_size=0.025,  # 25ms
        overlap=0.6
    )
    
    # Print some statistics
    print(f"Speech windows: {labeled_df['speech_label'].sum()}")
    print(f"Non-speech windows: {len(labeled_df) - labeled_df['speech_label'].sum()}")
    print(f"Speech percentage: {labeled_df['speech_label'].mean() * 100:.2f}%")
# Out:
# Found 256 audio files in C://Users//costac_c//Documents//GitHub//VAD//database//timit
# Processing 100_non_speech...
# Detected non-speech file 100_non_speech, skipping VAD processing
# Processing 100_speech...
# Marked entire file 100_speech as speech
# Processing 101_non_speech...
# Detected non-speech file 101_non_speech, skipping VAD processing
# Processing 101_speech...
# Marked entire file 101_speech as speech
# Processing 102_non_speech...
# Detected non-speech file 102_non_speech, skipping VAD processing
# Processing 102_speech...
# Marked entire file 102_speech as speech
# Processing 103_non_speech...
# Detected non-speech file 103_non_speech, skipping VAD processing
# Processing 103_speech...
# Marked entire file 103_speech as speech
# Processing 104_non_speech...
# Detected non-speech file 104_non_speech, skipping VAD processing
# Processing 104_speech...
# Marked entire file 104_speech as speech
# Processing 105_non_speech...
# Detected non-speech file 105_non_speech, skipping VAD processing
# Processing 105_speech...
# Marked entire file 105_speech as speech
# Processing 106_non_speech...
# Detected non-speech file 106_non_speech, skipping VAD processing
# Processing 106_speech...
# Marked entire file 106_speech as speech
# Processing 107_non_speech...
# Detected non-speech file 107_non_speech, skipping VAD processing
# Processing 107_speech...
# Marked entire file 107_speech as speech
# Processing 108_non_speech...
# Detected non-speech file 108_non_speech, skipping VAD processing
# Processing 108_speech...
# Marked entire file 108_speech as speech
# Processing 109_non_speech...
# Detected non-speech file 109_non_speech, skipping VAD processing
# Processing 109_speech...
# Marked entire file 109_speech as speech
# Processing 10_non_speech...
# Detected non-speech file 10_non_speech, skipping VAD processing
# Processing 10_speech...
# Marked entire file 10_speech as speech
# Processing 110_non_speech...
# Detected non-speech file 110_non_speech, skipping VAD processing
# Processing 110_speech...
# Marked entire file 110_speech as speech
# Processing 111_non_speech...
# Detected non-speech file 111_non_speech, skipping VAD processing
# Processing 111_speech...
# Marked entire file 111_speech as speech
# Processing 112_non_speech...
# Detected non-speech file 112_non_speech, skipping VAD processing
# Processing 112_speech...
# Marked entire file 112_speech as speech
# Processing 113_non_speech...
# Detected non-speech file 113_non_speech, skipping VAD processing
# Processing 113_speech...
# Marked entire file 113_speech as speech
# Processing 114_non_speech...
# Detected non-speech file 114_non_speech, skipping VAD processing
# Processing 114_speech...
# Marked entire file 114_speech as speech
# Processing 115_non_speech...
# Detected non-speech file 115_non_speech, skipping VAD processing
# Processing 115_speech...
# Marked entire file 115_speech as speech
# Processing 116_non_speech...
# Detected non-speech file 116_non_speech, skipping VAD processing
# Processing 116_speech...
# Marked entire file 116_speech as speech
# Processing 117_non_speech...
# Detected non-speech file 117_non_speech, skipping VAD processing
# Processing 117_speech...
# Marked entire file 117_speech as speech
# Processing 118_non_speech...
# Detected non-speech file 118_non_speech, skipping VAD processing
# Processing 118_speech...
# Marked entire file 118_speech as speech
# Processing 119_non_speech...
# Detected non-speech file 119_non_speech, skipping VAD processing
# Processing 119_speech...
# Marked entire file 119_speech as speech
# Processing 11_non_speech...
# Detected non-speech file 11_non_speech, skipping VAD processing
# Processing 11_speech...
# Marked entire file 11_speech as speech
# Processing 120_non_speech...
# Detected non-speech file 120_non_speech, skipping VAD processing
# Processing 120_speech...
# Marked entire file 120_speech as speech
# Processing 121_non_speech...
# Detected non-speech file 121_non_speech, skipping VAD processing
# Processing 121_speech...
# Marked entire file 121_speech as speech
# Processing 122_non_speech...
# Detected non-speech file 122_non_speech, skipping VAD processing
# Processing 122_speech...
# Marked entire file 122_speech as speech
# Processing 123_non_speech...
# Detected non-speech file 123_non_speech, skipping VAD processing
# Processing 123_speech...
# Marked entire file 123_speech as speech
# Processing 124_non_speech...
# Detected non-speech file 124_non_speech, skipping VAD processing
# Processing 124_speech...
# Marked entire file 124_speech as speech
# Processing 125_non_speech...
# Detected non-speech file 125_non_speech, skipping VAD processing
# Processing 125_speech...
# Marked entire file 125_speech as speech
# Processing 126_non_speech...
# Detected non-speech file 126_non_speech, skipping VAD processing
# Processing 126_speech...
# Marked entire file 126_speech as speech
# Processing 127_non_speech...
# Detected non-speech file 127_non_speech, skipping VAD processing
# Processing 127_speech...
# Marked entire file 127_speech as speech
# Processing 128_non_speech...
# Detected non-speech file 128_non_speech, skipping VAD processing
# Processing 128_speech...
# Marked entire file 128_speech as speech
# Processing 12_non_speech...
# Detected non-speech file 12_non_speech, skipping VAD processing
# Processing 12_speech...
# Marked entire file 12_speech as speech
# Processing 13_non_speech...
# Detected non-speech file 13_non_speech, skipping VAD processing
# Processing 13_speech...
# Marked entire file 13_speech as speech
# Processing 14_non_speech...
# Detected non-speech file 14_non_speech, skipping VAD processing
# Processing 14_speech...
# Marked entire file 14_speech as speech
# Processing 15_non_speech...
# Detected non-speech file 15_non_speech, skipping VAD processing
# Processing 15_speech...
# Marked entire file 15_speech as speech
# Processing 16_non_speech...
# Detected non-speech file 16_non_speech, skipping VAD processing
# Processing 16_speech...
# Marked entire file 16_speech as speech
# Processing 17_non_speech...
# Detected non-speech file 17_non_speech, skipping VAD processing
# Processing 17_speech...
# Marked entire file 17_speech as speech
# Processing 18_non_speech...
# Detected non-speech file 18_non_speech, skipping VAD processing
# Processing 18_speech...
# Marked entire file 18_speech as speech
# Processing 19_non_speech...
# Detected non-speech file 19_non_speech, skipping VAD processing
# Processing 19_speech...
# Marked entire file 19_speech as speech
# Processing 1_non_speech...
# Detected non-speech file 1_non_speech, skipping VAD processing
# Processing 1_speech...
# Marked entire file 1_speech as speech
# Processing 20_non_speech...
# Detected non-speech file 20_non_speech, skipping VAD processing
# Processing 20_speech...
# Marked entire file 20_speech as speech
# Processing 21_non_speech...
# Detected non-speech file 21_non_speech, skipping VAD processing
# Processing 21_speech...
# Marked entire file 21_speech as speech
# Processing 22_non_speech...
# Detected non-speech file 22_non_speech, skipping VAD processing
# Processing 22_speech...
# Marked entire file 22_speech as speech
# Processing 23_non_speech...
# Detected non-speech file 23_non_speech, skipping VAD processing
# Processing 23_speech...
# Marked entire file 23_speech as speech
# Processing 24_non_speech...
# Detected non-speech file 24_non_speech, skipping VAD processing
# Processing 24_speech...
# Marked entire file 24_speech as speech
# Processing 25_non_speech...
# Detected non-speech file 25_non_speech, skipping VAD processing
# Processing 25_speech...
# Marked entire file 25_speech as speech
# Processing 26_non_speech...
# Detected non-speech file 26_non_speech, skipping VAD processing
# Processing 26_speech...
# Marked entire file 26_speech as speech
# Processing 27_non_speech...
# Detected non-speech file 27_non_speech, skipping VAD processing
# Processing 27_speech...
# Marked entire file 27_speech as speech
# Processing 28_non_speech...
# Detected non-speech file 28_non_speech, skipping VAD processing
# Processing 28_speech...
# Marked entire file 28_speech as speech
# Processing 29_non_speech...
# Detected non-speech file 29_non_speech, skipping VAD processing
# Processing 29_speech...
# Marked entire file 29_speech as speech
# Processing 2_non_speech...
# Detected non-speech file 2_non_speech, skipping VAD processing
# Processing 2_speech...
# Marked entire file 2_speech as speech
# Processing 30_non_speech...
# Detected non-speech file 30_non_speech, skipping VAD processing
# Processing 30_speech...
# Marked entire file 30_speech as speech
# Processing 31_non_speech...
# Detected non-speech file 31_non_speech, skipping VAD processing
# Processing 31_speech...
# Marked entire file 31_speech as speech
# Processing 32_non_speech...
# Detected non-speech file 32_non_speech, skipping VAD processing
# Processing 32_speech...
# Marked entire file 32_speech as speech
# Processing 33_non_speech...
# Detected non-speech file 33_non_speech, skipping VAD processing
# Processing 33_speech...
# Marked entire file 33_speech as speech
# Processing 34_non_speech...
# Detected non-speech file 34_non_speech, skipping VAD processing
# Processing 34_speech...
# Marked entire file 34_speech as speech
# Processing 35_non_speech...
# Detected non-speech file 35_non_speech, skipping VAD processing
# Processing 35_speech...
# Marked entire file 35_speech as speech
# Processing 36_non_speech...
# Detected non-speech file 36_non_speech, skipping VAD processing
# Processing 36_speech...
# Marked entire file 36_speech as speech
# Processing 37_non_speech...
# Detected non-speech file 37_non_speech, skipping VAD processing
# Processing 37_speech...
# Marked entire file 37_speech as speech
# Processing 38_non_speech...
# Detected non-speech file 38_non_speech, skipping VAD processing
# Processing 38_speech...
# Marked entire file 38_speech as speech
# Processing 39_non_speech...
# Detected non-speech file 39_non_speech, skipping VAD processing
# Processing 39_speech...
# Marked entire file 39_speech as speech
# Processing 3_non_speech...
# Detected non-speech file 3_non_speech, skipping VAD processing
# Processing 3_speech...
# Marked entire file 3_speech as speech
# Processing 40_non_speech...
# Detected non-speech file 40_non_speech, skipping VAD processing
# Processing 40_speech...
# Marked entire file 40_speech as speech
# Processing 41_non_speech...
# Detected non-speech file 41_non_speech, skipping VAD processing
# Processing 41_speech...
# Marked entire file 41_speech as speech
# Processing 42_non_speech...
# Detected non-speech file 42_non_speech, skipping VAD processing
# Processing 42_speech...
# Marked entire file 42_speech as speech
# Processing 43_non_speech...
# Detected non-speech file 43_non_speech, skipping VAD processing
# Processing 43_speech...
# Marked entire file 43_speech as speech
# Processing 44_non_speech...
# Detected non-speech file 44_non_speech, skipping VAD processing
# Processing 44_speech...
# Marked entire file 44_speech as speech
# Processing 45_non_speech...
# Detected non-speech file 45_non_speech, skipping VAD processing
# Processing 45_speech...
# Marked entire file 45_speech as speech
# Processing 46_non_speech...
# Detected non-speech file 46_non_speech, skipping VAD processing
# Processing 46_speech...
# Marked entire file 46_speech as speech
# Processing 47_non_speech...
# Detected non-speech file 47_non_speech, skipping VAD processing
# Processing 47_speech...
# Marked entire file 47_speech as speech
# Processing 48_non_speech...
# Detected non-speech file 48_non_speech, skipping VAD processing
# Processing 48_speech...
# Marked entire file 48_speech as speech
# Processing 49_non_speech...
# Detected non-speech file 49_non_speech, skipping VAD processing
# Processing 49_speech...
# Marked entire file 49_speech as speech
# Processing 4_non_speech...
# Detected non-speech file 4_non_speech, skipping VAD processing
# Processing 4_speech...
# Marked entire file 4_speech as speech
# Processing 50_non_speech...
# Detected non-speech file 50_non_speech, skipping VAD processing
# Processing 50_speech...
# Marked entire file 50_speech as speech
# Processing 51_non_speech...
# Detected non-speech file 51_non_speech, skipping VAD processing
# Processing 51_speech...
# Marked entire file 51_speech as speech
# Processing 52_non_speech...
# Detected non-speech file 52_non_speech, skipping VAD processing
# Processing 52_speech...
# Marked entire file 52_speech as speech
# Processing 53_non_speech...
# Detected non-speech file 53_non_speech, skipping VAD processing
# Processing 53_speech...
# Marked entire file 53_speech as speech
# Processing 54_non_speech...
# Detected non-speech file 54_non_speech, skipping VAD processing
# Processing 54_speech...
# Marked entire file 54_speech as speech
# Processing 55_non_speech...
# Detected non-speech file 55_non_speech, skipping VAD processing
# Processing 55_speech...
# Marked entire file 55_speech as speech
# Processing 56_non_speech...
# Detected non-speech file 56_non_speech, skipping VAD processing
# Processing 56_speech...
# Marked entire file 56_speech as speech
# Processing 57_non_speech...
# Detected non-speech file 57_non_speech, skipping VAD processing
# Processing 57_speech...
# Marked entire file 57_speech as speech
# Processing 58_non_speech...
# Detected non-speech file 58_non_speech, skipping VAD processing
# Processing 58_speech...
# Marked entire file 58_speech as speech
# Processing 59_non_speech...
# Detected non-speech file 59_non_speech, skipping VAD processing
# Processing 59_speech...
# Marked entire file 59_speech as speech
# Processing 5_non_speech...
# Detected non-speech file 5_non_speech, skipping VAD processing
# Processing 5_speech...
# Marked entire file 5_speech as speech
# Processing 60_non_speech...
# Detected non-speech file 60_non_speech, skipping VAD processing
# Processing 60_speech...
# Marked entire file 60_speech as speech
# Processing 61_non_speech...
# Detected non-speech file 61_non_speech, skipping VAD processing
# Processing 61_speech...
# Marked entire file 61_speech as speech
# Processing 62_non_speech...
# Detected non-speech file 62_non_speech, skipping VAD processing
# Processing 62_speech...
# Marked entire file 62_speech as speech
# Processing 63_non_speech...
# Detected non-speech file 63_non_speech, skipping VAD processing
# Processing 63_speech...
# Marked entire file 63_speech as speech
# Processing 64_non_speech...
# Detected non-speech file 64_non_speech, skipping VAD processing
# Processing 64_speech...
# Marked entire file 64_speech as speech
# Processing 65_non_speech...
# Detected non-speech file 65_non_speech, skipping VAD processing
# Processing 65_speech...
# Marked entire file 65_speech as speech
# Processing 66_non_speech...
# Detected non-speech file 66_non_speech, skipping VAD processing
# Processing 66_speech...
# Marked entire file 66_speech as speech
# Processing 67_non_speech...
# Detected non-speech file 67_non_speech, skipping VAD processing
# Processing 67_speech...
# Marked entire file 67_speech as speech
# Processing 68_non_speech...
# Detected non-speech file 68_non_speech, skipping VAD processing
# Processing 68_speech...
# Marked entire file 68_speech as speech
# Processing 69_non_speech...
# Detected non-speech file 69_non_speech, skipping VAD processing
# Processing 69_speech...
# Marked entire file 69_speech as speech
# Processing 6_non_speech...
# Detected non-speech file 6_non_speech, skipping VAD processing
# Processing 6_speech...
# Marked entire file 6_speech as speech
# Processing 70_non_speech...
# Detected non-speech file 70_non_speech, skipping VAD processing
# Processing 70_speech...
# Marked entire file 70_speech as speech
# Processing 71_non_speech...
# Detected non-speech file 71_non_speech, skipping VAD processing
# Processing 71_speech...
# Marked entire file 71_speech as speech
# Processing 72_non_speech...
# Detected non-speech file 72_non_speech, skipping VAD processing
# Processing 72_speech...
# Marked entire file 72_speech as speech
# Processing 73_non_speech...
# Detected non-speech file 73_non_speech, skipping VAD processing
# Processing 73_speech...
# Marked entire file 73_speech as speech
# Processing 74_non_speech...
# Detected non-speech file 74_non_speech, skipping VAD processing
# Processing 74_speech...
# Marked entire file 74_speech as speech
# Processing 75_non_speech...
# Detected non-speech file 75_non_speech, skipping VAD processing
# Processing 75_speech...
# Marked entire file 75_speech as speech
# Processing 76_non_speech...
# Detected non-speech file 76_non_speech, skipping VAD processing
# Processing 76_speech...
# Marked entire file 76_speech as speech
# Processing 77_non_speech...
# Detected non-speech file 77_non_speech, skipping VAD processing
# Processing 77_speech...
# Marked entire file 77_speech as speech
# Processing 78_non_speech...
# Detected non-speech file 78_non_speech, skipping VAD processing
# Processing 78_speech...
# Marked entire file 78_speech as speech
# Processing 79_non_speech...
# Detected non-speech file 79_non_speech, skipping VAD processing
# Processing 79_speech...
# Marked entire file 79_speech as speech
# Processing 7_non_speech...
# Detected non-speech file 7_non_speech, skipping VAD processing
# Processing 7_speech...
# Marked entire file 7_speech as speech
# Processing 80_non_speech...
# Detected non-speech file 80_non_speech, skipping VAD processing
# Processing 80_speech...
# Marked entire file 80_speech as speech
# Processing 81_non_speech...
# Detected non-speech file 81_non_speech, skipping VAD processing
# Processing 81_speech...
# Marked entire file 81_speech as speech
# Processing 82_non_speech...
# Detected non-speech file 82_non_speech, skipping VAD processing
# Processing 82_speech...
# Marked entire file 82_speech as speech
# Processing 83_non_speech...
# Detected non-speech file 83_non_speech, skipping VAD processing
# Processing 83_speech...
# Marked entire file 83_speech as speech
# Processing 84_non_speech...
# Detected non-speech file 84_non_speech, skipping VAD processing
# Processing 84_speech...
# Marked entire file 84_speech as speech
# Processing 85_non_speech...
# Detected non-speech file 85_non_speech, skipping VAD processing
# Processing 85_speech...
# Marked entire file 85_speech as speech
# Processing 86_non_speech...
# Detected non-speech file 86_non_speech, skipping VAD processing
# Processing 86_speech...
# Marked entire file 86_speech as speech
# Processing 87_non_speech...
# Detected non-speech file 87_non_speech, skipping VAD processing
# Processing 87_speech...
# Marked entire file 87_speech as speech
# Processing 88_non_speech...
# Detected non-speech file 88_non_speech, skipping VAD processing
# Processing 88_speech...
# Marked entire file 88_speech as speech
# Processing 89_non_speech...
# Detected non-speech file 89_non_speech, skipping VAD processing
# Processing 89_speech...
# Marked entire file 89_speech as speech
# Processing 8_non_speech...
# Detected non-speech file 8_non_speech, skipping VAD processing
# Processing 8_speech...
# Marked entire file 8_speech as speech
# Processing 90_non_speech...
# Detected non-speech file 90_non_speech, skipping VAD processing
# Processing 90_speech...
# Marked entire file 90_speech as speech
# Processing 91_non_speech...
# Detected non-speech file 91_non_speech, skipping VAD processing
# Processing 91_speech...
# Marked entire file 91_speech as speech
# Processing 92_non_speech...
# Detected non-speech file 92_non_speech, skipping VAD processing
# Processing 92_speech...
# Marked entire file 92_speech as speech
# Processing 93_non_speech...
# Detected non-speech file 93_non_speech, skipping VAD processing
# Processing 93_speech...
# Marked entire file 93_speech as speech
# Processing 94_non_speech...
# Detected non-speech file 94_non_speech, skipping VAD processing
# Processing 94_speech...
# Marked entire file 94_speech as speech
# Processing 95_non_speech...
# Detected non-speech file 95_non_speech, skipping VAD processing
# Processing 95_speech...
# Marked entire file 95_speech as speech
# Processing 96_non_speech...
# Detected non-speech file 96_non_speech, skipping VAD processing
# Processing 96_speech...
# Marked entire file 96_speech as speech
# Processing 97_non_speech...
# Detected non-speech file 97_non_speech, skipping VAD processing
# Processing 97_speech...
# Marked entire file 97_speech as speech
# Processing 98_non_speech...
# Detected non-speech file 98_non_speech, skipping VAD processing
# Processing 98_speech...
# Marked entire file 98_speech as speech
# Processing 99_non_speech...
# Detected non-speech file 99_non_speech, skipping VAD processing
# Processing 99_speech...
# Marked entire file 99_speech as speech
# Processing 9_non_speech...
# Detected non-speech file 9_non_speech, skipping VAD processing
# Processing 9_speech...
# Marked entire file 9_speech as speech
# Processing complete. Results saved to speech_timestamps.txt
# Loading features from C://Users//costac_c//Documents//GitHub//VAD//database//features//16000_25_0.6_hamming_none_MAV_ZCR_F0_TTP_EQClasses.csv...
# Loading timestamps from C://Users//costac_c//Documents//GitHub//VAD//silero-vad//speech_timestamps.txt...
# Labeling windows...
# 100%|██████████| 256/256 [00:00<00:00, 27756.02it/s]
# Auto-labeled all windows in 100_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 100_speech as speech based on filename pattern
# Auto-labeled all windows in 101_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 101_speech as speech based on filename pattern
# Auto-labeled all windows in 102_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 102_speech as speech based on filename pattern
# Auto-labeled all windows in 103_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 103_speech as speech based on filename pattern
# Auto-labeled all windows in 104_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 104_speech as speech based on filename pattern
# Auto-labeled all windows in 105_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 105_speech as speech based on filename pattern
# Auto-labeled all windows in 106_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 106_speech as speech based on filename pattern
# Auto-labeled all windows in 107_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 107_speech as speech based on filename pattern
# Auto-labeled all windows in 108_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 108_speech as speech based on filename pattern
# Auto-labeled all windows in 109_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 109_speech as speech based on filename pattern
# Auto-labeled all windows in 10_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 10_speech as speech based on filename pattern
# Auto-labeled all windows in 110_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 110_speech as speech based on filename pattern
# Auto-labeled all windows in 111_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 111_speech as speech based on filename pattern
# Auto-labeled all windows in 112_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 112_speech as speech based on filename pattern
# Auto-labeled all windows in 113_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 113_speech as speech based on filename pattern
# Auto-labeled all windows in 114_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 114_speech as speech based on filename pattern
# Auto-labeled all windows in 115_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 115_speech as speech based on filename pattern
# Auto-labeled all windows in 116_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 116_speech as speech based on filename pattern
# Auto-labeled all windows in 117_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 117_speech as speech based on filename pattern
# Auto-labeled all windows in 118_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 118_speech as speech based on filename pattern
# Auto-labeled all windows in 119_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 119_speech as speech based on filename pattern
# Auto-labeled all windows in 11_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 11_speech as speech based on filename pattern
# Auto-labeled all windows in 120_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 120_speech as speech based on filename pattern
# Auto-labeled all windows in 121_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 121_speech as speech based on filename pattern
# Auto-labeled all windows in 122_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 122_speech as speech based on filename pattern
# Auto-labeled all windows in 123_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 123_speech as speech based on filename pattern
# Auto-labeled all windows in 124_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 124_speech as speech based on filename pattern
# Auto-labeled all windows in 125_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 125_speech as speech based on filename pattern
# Auto-labeled all windows in 126_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 126_speech as speech based on filename pattern
# Auto-labeled all windows in 127_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 127_speech as speech based on filename pattern
# Auto-labeled all windows in 128_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 128_speech as speech based on filename pattern
# Auto-labeled all windows in 12_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 12_speech as speech based on filename pattern
# Auto-labeled all windows in 13_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 13_speech as speech based on filename pattern
# Auto-labeled all windows in 14_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 14_speech as speech based on filename pattern
# Auto-labeled all windows in 15_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 15_speech as speech based on filename pattern
# Auto-labeled all windows in 16_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 16_speech as speech based on filename pattern
# Auto-labeled all windows in 17_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 17_speech as speech based on filename pattern
# Auto-labeled all windows in 18_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 18_speech as speech based on filename pattern
# Auto-labeled all windows in 19_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 19_speech as speech based on filename pattern
# Auto-labeled all windows in 1_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 1_speech as speech based on filename pattern
# Auto-labeled all windows in 20_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 20_speech as speech based on filename pattern
# Auto-labeled all windows in 21_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 21_speech as speech based on filename pattern
# Auto-labeled all windows in 22_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 22_speech as speech based on filename pattern
# Auto-labeled all windows in 23_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 23_speech as speech based on filename pattern
# Auto-labeled all windows in 24_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 24_speech as speech based on filename pattern
# Auto-labeled all windows in 25_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 25_speech as speech based on filename pattern
# Auto-labeled all windows in 26_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 26_speech as speech based on filename pattern
# Auto-labeled all windows in 27_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 27_speech as speech based on filename pattern
# Auto-labeled all windows in 28_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 28_speech as speech based on filename pattern
# Auto-labeled all windows in 29_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 29_speech as speech based on filename pattern
# Auto-labeled all windows in 2_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 2_speech as speech based on filename pattern
# Auto-labeled all windows in 30_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 30_speech as speech based on filename pattern
# Auto-labeled all windows in 31_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 31_speech as speech based on filename pattern
# Auto-labeled all windows in 32_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 32_speech as speech based on filename pattern
# Auto-labeled all windows in 33_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 33_speech as speech based on filename pattern
# Auto-labeled all windows in 34_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 34_speech as speech based on filename pattern
# Auto-labeled all windows in 35_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 35_speech as speech based on filename pattern
# Auto-labeled all windows in 36_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 36_speech as speech based on filename pattern
# Auto-labeled all windows in 37_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 37_speech as speech based on filename pattern
# Auto-labeled all windows in 38_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 38_speech as speech based on filename pattern
# Auto-labeled all windows in 39_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 39_speech as speech based on filename pattern
# Auto-labeled all windows in 3_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 3_speech as speech based on filename pattern
# Auto-labeled all windows in 40_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 40_speech as speech based on filename pattern
# Auto-labeled all windows in 41_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 41_speech as speech based on filename pattern
# Auto-labeled all windows in 42_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 42_speech as speech based on filename pattern
# Auto-labeled all windows in 43_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 43_speech as speech based on filename pattern
# Auto-labeled all windows in 44_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 44_speech as speech based on filename pattern
# Auto-labeled all windows in 45_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 45_speech as speech based on filename pattern
# Auto-labeled all windows in 46_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 46_speech as speech based on filename pattern
# Auto-labeled all windows in 47_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 47_speech as speech based on filename pattern
# Auto-labeled all windows in 48_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 48_speech as speech based on filename pattern
# Auto-labeled all windows in 49_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 49_speech as speech based on filename pattern
# Auto-labeled all windows in 4_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 4_speech as speech based on filename pattern
# Auto-labeled all windows in 50_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 50_speech as speech based on filename pattern
# Auto-labeled all windows in 51_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 51_speech as speech based on filename pattern
# Auto-labeled all windows in 52_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 52_speech as speech based on filename pattern
# Auto-labeled all windows in 53_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 53_speech as speech based on filename pattern
# Auto-labeled all windows in 54_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 54_speech as speech based on filename pattern
# Auto-labeled all windows in 55_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 55_speech as speech based on filename pattern
# Auto-labeled all windows in 56_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 56_speech as speech based on filename pattern
# Auto-labeled all windows in 57_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 57_speech as speech based on filename pattern
# Auto-labeled all windows in 58_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 58_speech as speech based on filename pattern
# Auto-labeled all windows in 59_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 59_speech as speech based on filename pattern
# Auto-labeled all windows in 5_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 5_speech as speech based on filename pattern
# Auto-labeled all windows in 60_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 60_speech as speech based on filename pattern
# Auto-labeled all windows in 61_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 61_speech as speech based on filename pattern
# Auto-labeled all windows in 62_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 62_speech as speech based on filename pattern
# Auto-labeled all windows in 63_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 63_speech as speech based on filename pattern
# Auto-labeled all windows in 64_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 64_speech as speech based on filename pattern
# Auto-labeled all windows in 65_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 65_speech as speech based on filename pattern
# Auto-labeled all windows in 66_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 66_speech as speech based on filename pattern
# Auto-labeled all windows in 67_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 67_speech as speech based on filename pattern
# Auto-labeled all windows in 68_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 68_speech as speech based on filename pattern
# Auto-labeled all windows in 69_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 69_speech as speech based on filename pattern
# Auto-labeled all windows in 6_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 6_speech as speech based on filename pattern
# Auto-labeled all windows in 70_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 70_speech as speech based on filename pattern
# Auto-labeled all windows in 71_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 71_speech as speech based on filename pattern
# Auto-labeled all windows in 72_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 72_speech as speech based on filename pattern
# Auto-labeled all windows in 73_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 73_speech as speech based on filename pattern
# Auto-labeled all windows in 74_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 74_speech as speech based on filename pattern
# Auto-labeled all windows in 75_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 75_speech as speech based on filename pattern
# Auto-labeled all windows in 76_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 76_speech as speech based on filename pattern
# Auto-labeled all windows in 77_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 77_speech as speech based on filename pattern
# Auto-labeled all windows in 78_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 78_speech as speech based on filename pattern
# Auto-labeled all windows in 79_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 79_speech as speech based on filename pattern
# Auto-labeled all windows in 7_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 7_speech as speech based on filename pattern
# Auto-labeled all windows in 80_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 80_speech as speech based on filename pattern
# Auto-labeled all windows in 81_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 81_speech as speech based on filename pattern
# Auto-labeled all windows in 82_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 82_speech as speech based on filename pattern
# Auto-labeled all windows in 83_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 83_speech as speech based on filename pattern
# Auto-labeled all windows in 84_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 84_speech as speech based on filename pattern
# Auto-labeled all windows in 85_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 85_speech as speech based on filename pattern
# Auto-labeled all windows in 86_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 86_speech as speech based on filename pattern
# Auto-labeled all windows in 87_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 87_speech as speech based on filename pattern
# Auto-labeled all windows in 88_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 88_speech as speech based on filename pattern
# Auto-labeled all windows in 89_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 89_speech as speech based on filename pattern
# Auto-labeled all windows in 8_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 8_speech as speech based on filename pattern
# Auto-labeled all windows in 90_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 90_speech as speech based on filename pattern
# Auto-labeled all windows in 91_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 91_speech as speech based on filename pattern
# Auto-labeled all windows in 92_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 92_speech as speech based on filename pattern
# Auto-labeled all windows in 93_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 93_speech as speech based on filename pattern
# Auto-labeled all windows in 94_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 94_speech as speech based on filename pattern
# Auto-labeled all windows in 95_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 95_speech as speech based on filename pattern
# Auto-labeled all windows in 96_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 96_speech as speech based on filename pattern
# Auto-labeled all windows in 97_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 97_speech as speech based on filename pattern
# Auto-labeled all windows in 98_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 98_speech as speech based on filename pattern
# Auto-labeled all windows in 99_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 99_speech as speech based on filename pattern
# Auto-labeled all windows in 9_non_speech as non-speech based on filename pattern
# Auto-labeled all windows in 9_speech as speech based on filename pattern
# Saving labeled features to C://Users//costac_c//Documents//GitHub//VAD//database//features//16000_25_0.6_hamming_none_MAV_ZCR_F0_TTP_EQClasses_labeled.csv...
# Done! Added speech labels for 37984 windows out of 80083 total.
# Speech windows: 37984
# Non-speech windows: 42099
# Speech percentage: 47.43%

# %%
# merge all speech chunks to one audio
save_audio('only_speech.wav',
           collect_chunks(speech_timestamps, wav), sampling_rate=SAMPLING_RATE)
Audio('only_speech.wav')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # merge all speech chunks to one audio
#       2 save_audio('only_speech.wav',
# ----> 3            collect_chunks(speech_timestamps, wav), sampling_rate=SAMPLING_RATE)
#       4 Audio('only_speech.wav')
#
# NameError: name 'speech_timestamps' is not defined

# %% [markdown]
# ## Entire audio inference

# %%
wav = read_audio('en_example.wav', sampling_rate=SAMPLING_RATE)
# audio is being splitted into 31.25 ms long pieces
# so output length equals ceil(input_length * 31.25 / SAMPLING_RATE)
predicts = model.audio_forward(wav, sr=SAMPLING_RATE)

# %% [markdown]
# ## Stream imitation example

# %%
## using VADIterator class

vad_iterator = VADIterator(model, sampling_rate=SAMPLING_RATE)
wav = read_audio(f'en_example.wav', sampling_rate=SAMPLING_RATE)

window_size_samples = 512 if SAMPLING_RATE == 16000 else 256
for i in range(0, len(wav), window_size_samples):
    chunk = wav[i: i+ window_size_samples]
    if len(chunk) < window_size_samples:
      break
    speech_dict = vad_iterator(chunk, return_seconds=True)
    if speech_dict:
        print(speech_dict, end=' ')
vad_iterator.reset_states() # reset model states after each audio
# Out:
# {'start': 0.0} {'end': 2.1} {'start': 2.7} {'end': 4.9} {'start': 5.0} {'end': 6.8} {'start': 9.3} {'end': 13.4} {'start': 13.5} {'end': 15.2} {'start': 15.3} {'end': 15.8} {'start': 16.3} {'end': 17.9} {'start': 18.4} {'end': 19.6} {'start': 20.3} {'end': 37.6} {'start': 38.0} {'end': 38.9} {'start': 39.9} {'end': 43.3} {'start': 43.6} {'end': 44.6} {'start': 45.0} {'end': 46.8} {'start': 48.8} {'end': 50.0} {'start': 51.1} {'end': 53.4} {'start': 53.5}

# %%
## just probabilities

wav = read_audio('en_example.wav', sampling_rate=SAMPLING_RATE)
speech_probs = []
window_size_samples = 512 if SAMPLING_RATE == 16000 else 256
for i in range(0, len(wav), window_size_samples):
    chunk = wav[i: i+ window_size_samples]
    if len(chunk) < window_size_samples:
      break
    speech_prob = model(chunk, SAMPLING_RATE).item()
    speech_probs.append(speech_prob)
vad_iterator.reset_states() # reset model states after each audio

print(speech_probs[:10]) # first 10 chunks predicts
# Out:
# [0.46508005261421204, 0.7383556962013245, 0.8762860894203186, 0.9573900699615479, 0.9656304121017456, 0.9954002499580383, 0.9969189167022705, 0.9968834519386292, 0.9967656135559082, 0.9967684745788574]
